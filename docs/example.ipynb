# %% [markdown]
# # Минимальный пример дефолтного использования движка AiZynthFinder

# %%
from aizynthfinder.interfaces import AiZynthApp
app = AiZynthApp("../aizynth-data/config.yml") # дефолтный конфиг
# Out:
# Loading template-based expansion policy model from /home/pustovalova_tv/chemrar_test_task/aizynth-data/uspto_model.onnx to uspto
# Loading templates from /home/pustovalova_tv/chemrar_test_task/aizynth-data/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /home/pustovalova_tv/chemrar_test_task/aizynth-data/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /home/pustovalova_tv/chemrar_test_task/aizynth-data/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /home/pustovalova_tv/chemrar_test_task/aizynth-data/uspto_filter_model.onnx to uspto
# Loading stock from /home/pustovalova_tv/chemrar_test_task/aizynth-data/zinc_stock.hdf5 to zinc
# Selected as molecule cost: zero
# Text(value='', continuous_update=False, description='SMILES')
# Output(layout=Layout(border='1px solid silver', height='180px', width='50%'))
# ...
